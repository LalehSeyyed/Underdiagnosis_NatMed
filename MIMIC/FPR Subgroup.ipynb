# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
FP5_age = pd.read_csv("./results22/FP5_age.csv")
FP4_age = pd.read_csv("./results19/FP4_age.csv")
FP3_age = pd.read_csv("./results38/FP3_age.csv")
FP2_age = pd.read_csv("./results47/FP2_age.csv")
FP1_age = pd.read_csv("./results31/FP1_age.csv")
FP_age = FP1_age.append([FP2_age, FP3_age,FP4_age, FP5_age])
F_age_df = FP_age.describe()

F_age_df.loc['mean']
1.96 * F_age_df.loc['std'] / np.sqrt(5)

FP5_race = pd.read_csv("./results22/FP5_race.csv")
FP4_race = pd.read_csv("./results19/FP4_race.csv")
FP3_race = pd.read_csv("./results38/FP3_race.csv")
FP2_race = pd.read_csv("./results47/FP2_race.csv")
FP1_race = pd.read_csv("./results31/FP1_race.csv")
FP_race = FP1_race.append([FP2_race, FP3_race,FP4_race, FP5_race])
F_race_df = FP_race.describe()

F_race_df.loc['mean']
1.96 * F_race_df.loc['std'] / np.sqrt(5)

FP5_insurance = pd.read_csv("./results22/FP5_insurance.csv")
FP4_insurance = pd.read_csv("./results19/FP4_insurance.csv")
FP3_insurance = pd.read_csv("./results38/FP3_insurance.csv")
FP2_insurance = pd.read_csv("./results47/FP2_insurance.csv")
FP1_insurance = pd.read_csv("./results31/FP1_insurance.csv")
FP_insurance = FP1_insurance.append([FP2_insurance, FP3_insurance,FP4_insurance, FP5_insurance])
FP_insurance_df = FP_insurance.describe()

FP_insurance_df.loc['mean']
1.96 * FP_insurance_df.loc['std'] / np.sqrt(5)

fig, ax = plt.subplots(figsize=(18,5))
fontsize = 14


#-------------------------------------------------------------------
ages = [ '80-', '60-80', '40-60', '20-40', '0-20']

ages_pos = np.arange(len(ages))

# This values are calculated in Confidence.ipynb
CTEs = [0.051,  0.117, 0.218,0.305,0.337]
error = [0.005, 0.008, 0.010,0.006,0.008]

ax.bar(ages_pos, CTEs, yerr=error, align='center', alpha=1, ecolor='black', capsize=10, color=['green'])#
#ax.bar(CTEs, ages_pos, yerr=error, align='center', alpha=0.5, ecolor='black', capsize=10)
#---------------------------------------------------------------------------


sex = [ 'MALE', 'FEMALE' ]

sex_pos = np.arange(6,len(sex)+6)

CTEs = [0.158,  0.188]
error = [0.007, 0.009]

ax.bar(sex_pos, CTEs, yerr=error, align='center', alpha=1, ecolor='black', capsize=10, color=['pink'])
#ax.bar(CTEs, Insurances_pos , yerr=error, align='center', alpha=0.5, ecolor='black', capsize=10)


#------------------------------------------------------------------------
races = [ 'WHITE', 'NATIVE', 'OTHER', 'ASIAN','HIPANIC', 'BLACK']
race_pos = np.arange(9,len(races)+9)

CTEs = [0.163,  0.166, 0.195,0.213,0.233,0.249]
error = [0.007, 0.023, 0.011,0.011,0.011,0.007]

ax.bar(race_pos, CTEs, yerr=error, align='center', alpha=1, ecolor='black', capsize=10, color=['brown'])
#ax.bar( CTEs, race_pos,  yerr=error, align='center', alpha=0.5, ecolor='black', capsize=10)
#--------------------------------------------------------------------------------------------------
Insurances = [ 'MEDICARE', 'OTHER', 'MEDICAID']

Insurances_pos = np.arange(16,len(Insurances)+16)

CTEs = [0.163,  0.179, 0.307]
error = [0.006, 0.005, 0.015]

ax.bar(Insurances_pos, CTEs, yerr=error, align='center', alpha=1, ecolor='black', capsize=10, color=['orange'])
#ax.bar(CTEs, Insurances_pos , yerr=error, align='center', alpha=0.5, ecolor='black', capsize=10)

labels = ['MALE', 'FEMALE',"",'80-', '60-80', '40-60', '20-40', '0-20',"",'WHITE', 'NATIVE', 'OTHER', 'ASIAN','HISPANIC', 'BLACK','', 'MEDICARE', 'OTHER', 'MEDICAID']
x_pos = np.arange(len(labels))
#y_labels = ['0.0', '0.1', '0.2', '0.3', '0.4']
#ax.set_ylabel('FALSE POSITIVE RATE')
ax.set_ylabel('"NF" FALSE POSITIVE RATE',fontsize = fontsize)
ax.set_xticks(x_pos)
ax.set_xticklabels(labels,fontsize = fontsize, rotation=90)
ax.set_yticklabels(y_labels,fontsize = fontsize)
#ax.set_title('A) AGE                                                           B)RACE                                                       C)INSURANCE')
#ax.text(1,0.45,'A) AGE                                                                      B)RACE                                                  C)INSURANCE',fontsize = 14.0)
ax.yaxis.grid(True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()

fig, ax = plt.subplots(figsize=(2,2))
fontsize = 10

# sex
sex = ('FEMALE', 'MALE', 'BLACK','HIPANIC','ASIAN', 'OTHER','WHITE')
sex_pos = np.arange(len(sex))
FPR = (0.362, 0.242, 0.414, 0.401, 0.353, 0.316, 0.182)
error = (0.022, 0.009, 0.018, 0.027, 0.021, 0.057, 0.013)

color = ['pink','pink', "brown", "brown", "brown", "brown", "brown"]
ax.barh(sex_pos, FPR, xerr=error, align='center',color=color)

# race
# race = ('BLACK','HIPANIC','ASIAN', 'OTHER','WHITE')
# race_pos = np.arange(3,len(races)+3)
# FPR =   (0.414, 0.401, 0.353, 0.316, 0.182)
# error = (0.018, 0.027, 0.021, 0.057, 0.013)
# ax.barh(race_pos, FPR, xerr=error, align='center',color=['brown'])


labels =['FEMALE', 'MALE', 'BLACK','HIPANIC','ASIAN', 'OTHER','WHITE']
x_pos = np.arange(len(labels))
x_labels = ['0.0', '0.1', '0.2', '0.3', '0.4']
ax.set_yticks(x_pos)
ax.set_yticklabels(labels, fontsize = fontsize)
ax.set_xticklabels(x_labels, fontsize = fontsize)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('FPR',fontsize = fontsize)
ax.set_title('MEDICAID', fontsize = fontsize)
ax.xaxis.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()

fig, ax = plt.subplots(figsize=(2,2))
fontsize = 10

# sex
sex = ('FEMALE', 'MALE', 'MEDICAID','MEDICARE','OTHER')
sex_pos = np.arange(len(sex))
FPR = (0.275, 0.207, 0.414, 0.276, 0.182, )
error = (0.007, 0.008, 0.018, 0.010, 0.004)

color = ['pink','pink', "orange", "orange", "orange"]
ax.barh(sex_pos, FPR, xerr=error, align='center',color=color)

# race
# race = ('BLACK','HIPANIC','ASIAN', 'OTHER','WHITE')
# race_pos = np.arange(3,len(races)+3)
# FPR =   (0.414, 0.401, 0.353, 0.316, 0.182)
# error = (0.018, 0.027, 0.021, 0.057, 0.013)
# ax.barh(race_pos, FPR, xerr=error, align='center',color=['brown'])


labels =['FEMALE', 'MALE', 'MEDICAID','MEDICARE','OTHER']
x_pos = np.arange(len(labels))
x_labels = ['0.0', '0.1', '0.2', '0.3', '0.4']
ax.set_yticks(x_pos)
ax.set_yticklabels(labels, fontsize = fontsize)
ax.set_xticklabels(x_labels, fontsize = fontsize)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('FPR',fontsize = fontsize)
ax.set_title('BLACK', fontsize = fontsize)
ax.xaxis.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()

fig, ax = plt.subplots(figsize=(2,2))
fontsize = 10

# sex
sex = ('FEMALE-ALL', 'MALE-ALL', 'FEMALE-CXR', 'MALE-CXR','FEMALE-NIH', 'MALE-NIH', 'MALE-CXP', 'FEMALE-CXP')
sex_pos = np.arange(len(sex))
FPR =   (0.393, 0.307, 0.729, 0.399, 0.444, 0.193, 0.202,0.117 )
error = (0.005, 0.011, 0.025, 0.029, 0.080, 0.017, 0.023, 0.021 )

color = ['pink','pink','m','m','r','r','c','c']
alpha = [1.0,1.0,0.8,0.8,0.6,0.6,0.4,0.4]
ax.barh(sex_pos, FPR, xerr=error, align='center',color=color)


labels =['FEMALE-ALL', 'MALE-ALL', 'FEMALE-CXR', 'MALE-CXR','FEMALE-NIH', 'MALE-NIH', 'MALE-CXP', 'FEMALE-CXP']
x_pos = np.arange(len(labels))
x_labels = ['0.0', '0.1', '0.2', '0.3', '0.4']
ax.set_yticks(x_pos)
ax.set_yticklabels(labels, fontsize = fontsize)
ax.set_xticklabels(x_labels, fontsize = fontsize)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('FPR',fontsize = fontsize)
ax.set_title('0-20', fontsize = fontsize)
ax.xaxis.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()

fig, ax = plt.subplots(figsize=(2,1.3))
fontsize = 10

# sex
sex = ('FEMALE', 'MALE')
sex_pos = np.arange(len(sex))
FPR =   (0.393, 0.307 )
error = (0.005, 0.011 )

color = ['pink','pink']

ax.barh(sex_pos, FPR, xerr=error, align='center',color=color)


labels =['FEMALE', 'MALE']
x_pos = np.arange(len(labels))
x_labels = ['0.0', '0.1', '0.2', '0.3', '0.4']
ax.set_yticks(x_pos)
ax.set_yticklabels(labels, fontsize = fontsize)
ax.set_xticklabels(x_labels, fontsize = fontsize)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('FPR',fontsize = fontsize)
ax.set_title('0-20', fontsize = fontsize)
ax.xaxis.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()

fig, ax = plt.subplots(figsize=(2,2))
fontsize = 10

# sex
sex = ('0-20', '20-40', '40-60', '60-80','80-')
sex_pos = np.arange(len(sex))
FPR =   (0.393, 0.382, 0.235, 0.129, 0.061 )
error = (0.005, 0.006, 0.011, 0.009, 0.007 )

color = ['green','green','green','green','green']
alpha = [1.0,1.0,0.8,0.8,0.6,0.6,0.4,0.4]
ax.barh(sex_pos, FPR, xerr=error, align='center',color=color)


labels =['0-20', '20-40', '40-60', '60-80','80-']
x_pos = np.arange(len(labels))
x_labels = ['0.0', '0.1', '0.2', '0.3', '0.4']
ax.set_yticks(x_pos)
ax.set_yticklabels(labels, fontsize = fontsize)
ax.set_xticklabels(x_labels, fontsize = fontsize)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('FPR',fontsize = fontsize)
ax.set_title('FEMALE', fontsize = fontsize)
ax.xaxis.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()

fig, ax = plt.subplots(figsize=(2,2))
fontsize = 10

# sex
sex = ('0-20', '20-40', '40-60', '60-80','80-')
sex_pos = np.arange(len(sex))
FPR =   (0.393, 0.382, 0.235, 0.129, 0.061 )
error = (0.005, 0.006, 0.011, 0.009, 0.007 )

color = ['green','green','green','green','green']

ax.bar(sex_pos, FPR, yerr=error, align='center',color=color)


labels =['0-20', '20-40', '40-60', '60-80','80-']
x_pos = np.arange(len(labels))
x_labels = ['0.0', '0.1', '0.2', '0.3', '0.4']
ax.set_xticks(x_pos)
ax.set_xticklabels(labels, fontsize = fontsize,  rotation=90)
ax.set_yticklabels(x_labels, fontsize = fontsize)
#ax.invert_yaxis()  # labels read top-to-bottom
ax.set_ylabel('FPR',fontsize = fontsize)
ax.set_title('FEMALE', fontsize = fontsize)
ax.yaxis.grid(True)
plt.show()

# %%
np.random.seed(19680801)


plt.rcdefaults()

fig, ax = plt.subplots(figsize=(1,2))
fontsize = 10

# sex
sex = ('FEMALE', 'MALE')
sex_pos = np.arange(len(sex))
FPR =   (0.393, 0.307 )
error = (0.005, 0.011 )

color = ['pink','pink']

ax.bar(sex_pos, FPR, yerr=error, align='center',color=color)


labels =['FEMALE', 'MALE']
x_pos = np.arange(len(labels))
x_labels = ['0.0', '0.1', '0.2', '0.3', '0.4']
ax.set_xticks(x_pos)
ax.set_xticklabels(labels, fontsize = fontsize, rotation=90)
ax.set_yticklabels(x_labels, fontsize = fontsize)
# ax.invert_yaxis()  # labels read top-to-bottom
ax.set_ylabel('FPR',fontsize = fontsize)
ax.set_title('0-20', fontsize = fontsize)
ax.yaxis.grid(True)
plt.show()

# %%
plt.rcdefaults()

fig, ax = plt.subplots(figsize=(2,2))
fontsize = 10

# sex
sex = ('FEMALE', 'MALE', 'MEDICAID','MEDICARE','OTHER')
sex_pos = np.arange(len(sex))
FPR = (0.275, 0.207, 0.414, 0.276, 0.182, )
error = (0.007, 0.008, 0.018, 0.010, 0.004)

color = ['pink','pink', "orange", "orange", "orange"]
ax.bar(sex_pos, FPR, yerr=error, align='center',color=color)



labels =['FEMALE', 'MALE', 'MEDICAID','MEDICARE','OTHER']
x_pos = np.arange(len(labels))
x_labels = ['0.0', '0.1', '0.2', '0.3', '0.4']
ax.set_xticks(x_pos)
ax.set_xticklabels(labels, fontsize = fontsize, rotation=90 )
ax.set_yticklabels(x_labels, fontsize = fontsize)
#ax.invert_yaxis()  # labels read top-to-bottom
ax.set_ylabel('FPR',fontsize = fontsize)
ax.set_title('BLACK', fontsize = fontsize)
ax.yaxis.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()

fig, ax = plt.subplots(figsize=(2.2,2))
fontsize = 10

# sex
sex = ('FEMALE', 'MALE', 'BLACK','HIPANIC','ASIAN', 'OTHER','WHITE')
sex_pos = np.arange(len(sex))
FPR = (0.362, 0.242, 0.414, 0.401, 0.353, 0.316, 0.182)
error = (0.022, 0.009, 0.018, 0.027, 0.021, 0.057, 0.013)

color = ['pink','pink', "brown", "brown", "brown", "brown", "brown"]
ax.bar(sex_pos, FPR, yerr=error, align='center',color=color)


labels =['FEMALE', 'MALE', 'BLACK','HIPANIC','ASIAN', 'OTHER','WHITE']
x_pos = np.arange(len(labels))
x_labels = ['0.0', '0.1', '0.2', '0.3', '0.4']
ax.set_xticks(x_pos)
ax.set_xticklabels(labels, fontsize = fontsize, rotation=90)
ax.set_yticklabels(x_labels, fontsize = fontsize)
#ax.invert_yaxis()  # labels read top-to-bottom
ax.set_ylabel('FPR',fontsize = fontsize)
ax.set_title('MEDICAID', fontsize = fontsize)
ax.yaxis.grid(True)
plt.show()
